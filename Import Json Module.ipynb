# %%
import json

# %%
with open('/Users/annette/Documents/response.json') as f:
  data = json.load(f)
# Output
print(data)
# Out:
# {'count': 83, 'results': [{'key': 'workspaces', 'id': '25400845'}, {'key': 'workspaces', 'id': '28653915'}, {'key': 'workspaces', 'id': '25959455'}, {'key': 'workspaces', 'id': '12601267'}, {'key': 'workspaces', 'id': '12642747'}, {'key': 'workspaces', 'id': '28453435'}, {'key': 'workspaces', 'id': '25536895'}, {'key': 'workspaces', 'id': '29233735'}, {'key': 'workspaces', 'id': '27214135'}, {'key': 'workspaces', 'id': '28472865'}, {'key': 'workspaces', 'id': '22048705'}, {'key': 'workspaces', 'id': '27251805'}, {'key': 'workspaces', 'id': '27211465'}, {'key': 'workspaces', 'id': '24747815'}, {'key': 'workspaces', 'id': '27469455'}, {'key': 'workspaces', 'id': '28093725'}, {'key': 'workspaces', 'id': '28731315'}, {'key': 'workspaces', 'id': '22547995'}, {'key': 'workspaces', 'id': '26377885'}, {'key': 'workspaces', 'id': '29020165'}], 'workspaces': {'25400845': {'title': 'DCTV - SOW-3 - Making Technology a Strategic Advantage ', 'account_id': 3730977, 'archived': False, 'description'
# ...
